# %% [markdown]
# Clean and merge the merge_df

# %%
import pandas as pd

# %%
airlines= pd.read_csv('airlines.csv')
airplanes= pd.read_csv('airplanes.csv')
airports = pd.read_csv('airports.csv')
routes =  pd.read_csv('routes.csv')

# %% [markdown]
# kjdhfuidhgsfuds

# %%
# Drop the first column and reset the index
airlines_df = airlines.drop(airlines.columns[0], axis=1).reset_index(drop=True)
airports_df= airports.drop(airports.columns[0], axis=1).reset_index(drop=True)
airports_df = airports_df.drop(['Type', 'Source'], axis=1)
routes_df= routes.drop(routes.columns[0], axis=1).reset_index(drop=True)
airplanes_df= airplanes.drop(airplanes.columns[0], axis=1).reset_index(drop=True)

# %%
merge_df_1 = pd.merge(routes_df, airports_df, left_on="Source airport", right_on="IATA")
merge_df_1 = merge_df_1.rename(columns={"Country": "Source country","Latitude": "latitude_source","Longitude": "longitude_source"})
merge_df_1.head(5)
# Out:
#   Airline Airline ID Source airport Source airport ID Destination airport  \
# 0      2B        410            AER              2965                 KZN
# 1      7J       9531            AER              2965                 DYU
# 2      9U       1073            AER              2965                 KIV
# 3      B2       1478            AER              2965                 MSQ
# 4      HY       5281            AER              2965                 TAS
#
#   Destination airport ID Codeshare  Stops Equipment  Airport ID  ...   City  \
# 0                   2990       NaN      0       CR2        2965  ...  Sochi
# 1                   2979       NaN      0       735        2965  ...  Sochi
# 2                   1735       NaN      0       EM2        2965  ...  Sochi
# 3                   2954       NaN      0   735 CRJ        2965  ...  Sochi
# 4                   2983       NaN      0       767        2965  ...  Sochi
#
#   Source country IATA  ICAO latitude_source  longitude_source  Altitude  \
# 0         Russia  AER  URSS       43.449902           39.9566        89
# 1         Russia  AER  URSS       43.449902           39.9566        89
# 2         Russia  AER  URSS       43.449902           39.9566        89
# 3         Russia  AER  URSS       43.449902           39.9566        89
# 4         Russia  AER  URSS       43.449902           39.9566        89
#
#    Timezone DST Tz database time zone
# 0         3   N         Europe/Moscow
# 1         3   N         Europe/Moscow
# 2         3   N         Europe/Moscow
# 3         3   N         Europe/Moscow
# 4         3   N         Europe/Moscow
#
# [5 rows x 21 columns]

# %%
# Assuming merge_df is your DataFrame
column_names = merge_df_1.columns.tolist()

# Print or use the column names as needed
print(column_names)
# Out:
# ['Airline', 'Airline ID', 'Source airport', 'Source airport ID', 'Destination airport', 'Destination airport ID', 'Codeshare', 'Stops', 'Equipment', 'Airport ID', 'Name', 'City', 'Source country', 'IATA', 'ICAO', 'latitude_source', 'longitude_source', 'Altitude', 'Timezone', 'DST', 'Tz database time zone']

# %%
merge_df_2 = pd.merge(merge_df_1,airports_df[["IATA", "Country", "Latitude", "Longitude"]],left_on="Source airport",right_on="IATA")
merge_df_2 = merge_df_2.rename(columns={'IATA_x':"IATA", "Country": "Destination country","Latitude": "latitude_destination","Longitude": "longitude_destination"})
merge_df_2
# Out:
#       Airline Airline ID Source airport Source airport ID Destination airport  \
# 0          2B        410            AER              2965                 KZN
# 1          7J       9531            AER              2965                 DYU
# 2          9U       1073            AER              2965                 KIV
# 3          B2       1478            AER              2965                 MSQ
# 4          HY       5281            AER              2965                 TAS
# ...       ...        ...            ...               ...                 ...
# 67252      ZL       4178            TRO              6794                 GFN
# 67253      ZL       4178            TRO              6794                 SYD
# 67254      ZL       4178            WIN              6337                 LRE
# 67255      ZL       4178            WIN              6337                 TSV
# 67256      ZL       4178            WYA              6334                 ADL
#
#       Destination airport ID Codeshare  Stops Equipment  Airport ID  ...  \
# 0                       2990       NaN      0       CR2        2965  ...
# 1                       2979       NaN      0       735        2965  ...
# 2                       1735       NaN      0       EM2        2965  ...
# 3                       2954       NaN      0   735 CRJ        2965  ...
# 4                       2983       NaN      0       767        2965  ...
# ...                      ...       ...    ...       ...         ...  ...
# 67252                   6792       NaN      0       SF3        6794  ...
# 67253                   3361       NaN      0       SF3        6794  ...
# 67254                   6289       NaN      0       SF3        6337  ...
# 67255                   3330       NaN      0       SF3        6337  ...
# 67256                   3341       NaN      0       SF3        6334  ...
#
#       latitude_source longitude_source Altitude Timezone DST  \
# 0           43.449902        39.956600       89        3   N
# 1           43.449902        39.956600       89        3   N
# 2           43.449902        39.956600       89        3   N
# 3           43.449902        39.956600       89        3   N
# 4           43.449902        39.956600       89        3   N
# ...               ...              ...      ...      ...  ..
# 67252      -31.888599       152.514008       38       10   U
# 67253      -31.888599       152.514008       38       10   U
# 67254      -22.363600       143.085999      638       10   O
# 67255      -22.363600       143.085999      638       10   O
# 67256      -33.058899       137.514008       41      9.5   O
#
#        Tz database time zone  IATA_y  Destination country  \
# 0              Europe/Moscow     AER               Russia
# 1              Europe/Moscow     AER               Russia
# 2              Europe/Moscow     AER               Russia
# 3              Europe/Moscow     AER               Russia
# 4              Europe/Moscow     AER               Russia
# ...                      ...     ...                  ...
# 67252       Australia/Sydney     TRO            Australia
# 67253       Australia/Sydney     TRO            Australia
# 67254     Australia/Brisbane     WIN            Australia
# 67255     Australia/Brisbane     WIN            Australia
# 67256     Australia/Adelaide     WYA            Australia
#
#       latitude_destination longitude_destination
# 0                43.449902             39.956600
# 1                43.449902             39.956600
# 2                43.449902             39.956600
# 3                43.449902             39.956600
# 4                43.449902             39.956600
# ...                    ...                   ...
# 67252           -31.888599            152.514008
# 67253           -31.888599            152.514008
# 67254           -22.363600            143.085999
# 67255           -22.363600            143.085999
# 67256           -33.058899            137.514008
#
# [67257 rows x 25 columns]

# %%
# Assuming merge_df is your DataFrame
column_names = merge_df_2.columns.tolist()

# Print or use the column names as needed
print(column_names)
# Out:
# ['Airline', 'Airline ID', 'Source airport', 'Source airport ID', 'Destination airport', 'Destination airport ID', 'Codeshare', 'Stops', 'Equipment', 'Airport ID', 'Name', 'City', 'Source country', 'IATA', 'ICAO', 'latitude_source', 'longitude_source', 'Altitude', 'Timezone', 'DST', 'Tz database time zone', 'IATA_y', 'Destination country', 'latitude_destination', 'longitude_destination']

# %%
merge_df_2 = merge_df_2.dropna(subset=["Source country", "Destination country"])
merge_df_2
# Out:
#       Airline Airline ID Source airport Source airport ID Destination airport  \
# 0          2B        410            AER              2965                 KZN
# 1          7J       9531            AER              2965                 DYU
# 2          9U       1073            AER              2965                 KIV
# 3          B2       1478            AER              2965                 MSQ
# 4          HY       5281            AER              2965                 TAS
# ...       ...        ...            ...               ...                 ...
# 67252      ZL       4178            TRO              6794                 GFN
# 67253      ZL       4178            TRO              6794                 SYD
# 67254      ZL       4178            WIN              6337                 LRE
# 67255      ZL       4178            WIN              6337                 TSV
# 67256      ZL       4178            WYA              6334                 ADL
#
#       Destination airport ID Codeshare  Stops Equipment  Airport ID  ...  \
# 0                       2990       NaN      0       CR2        2965  ...
# 1                       2979       NaN      0       735        2965  ...
# 2                       1735       NaN      0       EM2        2965  ...
# 3                       2954       NaN      0   735 CRJ        2965  ...
# 4                       2983       NaN      0       767        2965  ...
# ...                      ...       ...    ...       ...         ...  ...
# 67252                   6792       NaN      0       SF3        6794  ...
# 67253                   3361       NaN      0       SF3        6794  ...
# 67254                   6289       NaN      0       SF3        6337  ...
# 67255                   3330       NaN      0       SF3        6337  ...
# 67256                   3341       NaN      0       SF3        6334  ...
#
#       latitude_source longitude_source Altitude Timezone DST  \
# 0           43.449902        39.956600       89        3   N
# 1           43.449902        39.956600       89        3   N
# 2           43.449902        39.956600       89        3   N
# 3           43.449902        39.956600       89        3   N
# 4           43.449902        39.956600       89        3   N
# ...               ...              ...      ...      ...  ..
# 67252      -31.888599       152.514008       38       10   U
# 67253      -31.888599       152.514008       38       10   U
# 67254      -22.363600       143.085999      638       10   O
# 67255      -22.363600       143.085999      638       10   O
# 67256      -33.058899       137.514008       41      9.5   O
#
#        Tz database time zone  IATA_y  Destination country  \
# 0              Europe/Moscow     AER               Russia
# 1              Europe/Moscow     AER               Russia
# 2              Europe/Moscow     AER               Russia
# 3              Europe/Moscow     AER               Russia
# 4              Europe/Moscow     AER               Russia
# ...                      ...     ...                  ...
# 67252       Australia/Sydney     TRO            Australia
# 67253       Australia/Sydney     TRO            Australia
# 67254     Australia/Brisbane     WIN            Australia
# 67255     Australia/Brisbane     WIN            Australia
# 67256     Australia/Adelaide     WYA            Australia
#
#       latitude_destination longitude_destination
# 0                43.449902             39.956600
# 1                43.449902             39.956600
# 2                43.449902             39.956600
# 3                43.449902             39.956600
# 4                43.449902             39.956600
# ...                    ...                   ...
# 67252           -31.888599            152.514008
# 67253           -31.888599            152.514008
# 67254           -22.363600            143.085999
# 67255           -22.363600            143.085999
# 67256           -33.058899            137.514008
#
# [67257 rows x 25 columns]

# %%
#Drop the columns that I dont need
merge_df_2.drop(columns=['IATA_y'], inplace=True)

# %%
# Assuming merge_df is your DataFrame
column_names = merge_df_2.columns.tolist()

# Print or use the column names as needed
print(column_names)
# Out:
# ['Airline', 'Airline ID', 'Source airport', 'Source airport ID', 'Destination airport', 'Destination airport ID', 'Codeshare', 'Stops', 'Equipment', 'Airport ID', 'Name', 'City', 'Source country', 'IATA', 'ICAO', 'latitude_source', 'longitude_source', 'Altitude', 'Timezone', 'DST', 'Tz database time zone', 'Destination country', 'latitude_destination', 'longitude_destination']

# %%
merge_df_3=pd.merge(merge_df_2,airlines_df,left_on="Airline",right_on="IATA")
merge_df_3 = merge_df_3.rename(columns={'Name_y':"Name Airline",'IATA_x':'IATA', 'ICAO_x':'ICAO','Name_x':'Airport Name','Airline ID_x':'Airline ID'})
merge_df_3.drop(columns=['Airline ID_y', 'IATA_y','ICAO_y','Alias','Airport ID','Timezone', 'DST', 'Tz database time zone'], inplace=True)
merge_df_3
# Out:
#       Airline Airline ID Source airport Source airport ID Destination airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# ...       ...        ...            ...               ...                 ...
# 76868      TY       2825            TOU              2003                 GEA
# 76869      TY       2825            UVE              2004                 GEA
# 76870      TY       2825            UVE              2004                 GEA
# 76871      TY       2825            UVE              2004                 LIF
# 76872      TY       2825            UVE              2004                 LIF
#
#       Destination airport ID Codeshare  Stops Equipment  \
# 0                       2990       NaN      0       CR2
# 1                       2990       NaN      0       CR2
# 2                       2962       NaN      0       CR2
# 3                       2990       NaN      0       CR2
# 4                       4078       NaN      0       CR2
# ...                      ...       ...    ...       ...
# 76868                   2001       NaN      0       DHT
# 76869                   2001       NaN      0   ATR DHT
# 76870                   2001       NaN      0   ATR DHT
# 76871                   2000       NaN      0       DHT
# 76872                   2000       NaN      0       DHT
#
#                         Airport Name  ... latitude_source longitude_source  \
# 0        Sochi International Airport  ...       43.449902        39.956600
# 1                  Astrakhan Airport  ...       46.283298        48.006302
# 2                  Astrakhan Airport  ...       46.283298        48.006302
# 3      Chelyabinsk Balandino Airport  ...       55.305801        61.503300
# 4      Chelyabinsk Balandino Airport  ...       55.305801        61.503300
# ...                              ...  ...             ...              ...
# 76868                  Touho Airport  ...      -20.790001       165.259003
# 76869                  Ouvéa Airport  ...      -20.640600       166.572998
# 76870                  Ouvéa Airport  ...      -20.640600       166.572998
# 76871                  Ouvéa Airport  ...      -20.640600       166.572998
# 76872                  Ouvéa Airport  ...      -20.640600       166.572998
#
#       Altitude Destination country  latitude_destination  \
# 0           89              Russia             43.449902
# 1          -65              Russia             46.283298
# 2          -65              Russia             46.283298
# 3          769              Russia             55.305801
# 4          769              Russia             55.305801
# ...        ...                 ...                   ...
# 76868       10       New Caledonia            -20.790001
# 76869       23       New Caledonia            -20.640600
# 76870       23       New Caledonia            -20.640600
# 76871       23       New Caledonia            -20.640600
# 76872       23       New Caledonia            -20.640600
#
#        longitude_destination  Name Airline    Callsign   Country  Active
# 0                  39.956600    Aerocondor  AEROCONDOR  Portugal       Y
# 1                  48.006302    Aerocondor  AEROCONDOR  Portugal       Y
# 2                  48.006302    Aerocondor  AEROCONDOR  Portugal       Y
# 3                  61.503300    Aerocondor  AEROCONDOR  Portugal       Y
# 4                  61.503300    Aerocondor  AEROCONDOR  Portugal       Y
# ...                      ...           ...         ...       ...     ...
# 76868             165.259003     Iberworld         NaN     Spain       Y
# 76869             166.572998       Air Cal      AIRCAL    France       N
# 76870             166.572998     Iberworld         NaN     Spain       Y
# 76871             166.572998       Air Cal      AIRCAL    France       N
# 76872             166.572998     Iberworld         NaN     Spain       Y
#
# [76873 rows x 24 columns]

# %%
# Assuming merge_df is your DataFrame
column_names = merge_df_3.columns.tolist()

# Print or use the column names as needed
print(column_names)
# Out:
# ['Airline', 'Airline ID', 'Source airport', 'Source airport ID', 'Destination airport', 'Destination airport ID', 'Codeshare', 'Stops', 'Equipment', 'Airport Name', 'City', 'Source country', 'IATA', 'ICAO', 'latitude_source', 'longitude_source', 'Altitude', 'Destination country', 'latitude_destination', 'longitude_destination', 'Name Airline', 'Callsign', 'Country', 'Active']

# %%
airplanes_df = airplanes_df.rename(columns={'IATA code':"IATA"})
merge_df=pd.merge(merge_df_3,airplanes_df, how="left")
merge_df
# Out:
#       Airline Airline ID Source airport Source airport ID Destination airport  \
# 0          2B        410            AER              2965                 KZN
# 1          2B        410            ASF              2966                 KZN
# 2          2B        410            ASF              2966                 MRV
# 3          2B        410            CEK              2968                 KZN
# 4          2B        410            CEK              2968                 OVB
# ...       ...        ...            ...               ...                 ...
# 76924      TY       2825            TOU              2003                 GEA
# 76925      TY       2825            UVE              2004                 GEA
# 76926      TY       2825            UVE              2004                 GEA
# 76927      TY       2825            UVE              2004                 LIF
# 76928      TY       2825            UVE              2004                 LIF
#
#       Destination airport ID Codeshare  Stops Equipment  \
# 0                       2990       NaN      0       CR2
# 1                       2990       NaN      0       CR2
# 2                       2962       NaN      0       CR2
# 3                       2990       NaN      0       CR2
# 4                       4078       NaN      0       CR2
# ...                      ...       ...    ...       ...
# 76924                   2001       NaN      0       DHT
# 76925                   2001       NaN      0   ATR DHT
# 76926                   2001       NaN      0   ATR DHT
# 76927                   2000       NaN      0       DHT
# 76928                   2000       NaN      0       DHT
#
#                         Airport Name  ... Altitude Destination country  \
# 0        Sochi International Airport  ...       89              Russia
# 1                  Astrakhan Airport  ...      -65              Russia
# 2                  Astrakhan Airport  ...      -65              Russia
# 3      Chelyabinsk Balandino Airport  ...      769              Russia
# 4      Chelyabinsk Balandino Airport  ...      769              Russia
# ...                              ...  ...      ...                 ...
# 76924                  Touho Airport  ...       10       New Caledonia
# 76925                  Ouvéa Airport  ...       23       New Caledonia
# 76926                  Ouvéa Airport  ...       23       New Caledonia
# 76927                  Ouvéa Airport  ...       23       New Caledonia
# 76928                  Ouvéa Airport  ...       23       New Caledonia
#
#       latitude_destination longitude_destination  Name Airline    Callsign  \
# 0                43.449902             39.956600    Aerocondor  AEROCONDOR
# 1                46.283298             48.006302    Aerocondor  AEROCONDOR
# 2                46.283298             48.006302    Aerocondor  AEROCONDOR
# 3                55.305801             61.503300    Aerocondor  AEROCONDOR
# 4                55.305801             61.503300    Aerocondor  AEROCONDOR
# ...                    ...                   ...           ...         ...
# 76924           -20.790001            165.259003     Iberworld         NaN
# 76925           -20.640600            166.572998       Air Cal      AIRCAL
# 76926           -20.640600            166.572998     Iberworld         NaN
# 76927           -20.640600            166.572998       Air Cal      AIRCAL
# 76928           -20.640600            166.572998     Iberworld         NaN
#
#         Country Active  Name  ICAO code
# 0      Portugal      Y   NaN        NaN
# 1      Portugal      Y   NaN        NaN
# 2      Portugal      Y   NaN        NaN
# 3      Portugal      Y   NaN        NaN
# 4      Portugal      Y   NaN        NaN
# ...         ...    ...   ...        ...
# 76924     Spain      Y   NaN        NaN
# 76925    France      N   NaN        NaN
# 76926     Spain      Y   NaN        NaN
# 76927    France      N   NaN        NaN
# 76928     Spain      Y   NaN        NaN
#
# [76929 rows x 26 columns]
